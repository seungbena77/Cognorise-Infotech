# %% [markdown]
# ##  Machine Learning for  CAR PRICE PREDICTION
#
# ##### This dataset provides a comprehensive overview for car price prediction. It encapsulates a range of features, from basic demographics to financial details, that can be instrumental in assessing the creditworthiness of an individual
#
#
# Dataset used in the project can be download here:https://www.kaggle.com/datasets/goyalshalini93/car-data?resource=download&select=CarPrice_Assignment.csv
#
#  #### Dataset Key Information :
#  <p style = "color:#226666">The CAR PRICE PREDICTION is explained by the following factors:</p>
#
#    - <p style = "color:#226666">Car_ID : Assigned ID to each car (numeric) </p>
#   - <p style = "color:#226666">Symboling :  refers to risk rating (numeric) </p>
#   - <p style = "color:#226666">CarName : Assigned name for the car (categorical) </p>
#   - <p style = "color:#226666">Fueltype : Type of gas used by the car (categorical) </p>
#   - <p style = "color:#226666">Aspiration : engine's design and performance (categorical) </p>
#   - <p style = "color:#226666">Door number : Number of doors car has (numeric) </p>
#   - <p style = "color:#226666">Car body: body design structure (categorical) </p>
#   - <p style = "color:#226666">Drive wheel : Wheel drive design structure (categorical) </p>
#   - <p style = "color:#226666">Engine location : Engine location of the car (categorical) </p>
#   - <p style = "color:#226666">Wheelbase : Distance btw the front and rear wheels of a vehicle (numeric) </p>
#   - <p style = "color:#226666">Carlength : Overall length of the vehicle(numeric) </p>
#   - <p style = "color:#226666">Carwidth : Overall Widenes of the vehicle(numeric) </p>
#   - <p style = "color:#226666">Carheight : Overall height of the vehicle(numeric) </p>
#   - <p style = "color:#226666">Car weight : Overall weight of the vehicle(numeric) </p>
#   - <p style = "color:#226666">Engine type : Type of engine used in the vehicle(categorical) </p>
#   - <p style = "color:#226666">Cylinder number : Number of cylinders in the engine(categorical) </p>
#   - <p style = "color:#226666">Enginesize : Size of the vehicle engine(numeric) </p>
#   - <p style = "color:#226666">Fuel system   : uel delivery system used in the vehicle. (categorical) </p>
#   - <p style = "color:#226666">Boreratio : ratio of the bore (the diameter of the engine cylinders)(numeric) </p>
#   - <p style = "color:#226666">Stroke : Distance the piston travels within the cylinde(numeric) </p>
#   - <p style = "color:#226666">Compressionratio : Ratio of the maximum to the minimum volume in the combustion chamber of an engine(numeric) </p>
#    - <p style = "color:#226666">Horsepower  : Engine's power output(numeric) </p>
#    - <p style = "color:#226666">Peakrpm :  Maximum engine speed at which the engine can operate effectively(numeric) </p>
#    - <p style = "color:#226666">Citympg :  fuel efficiency of a vehicle measured in miles per gallon (MPG)(numeric) </p>
#    - <p style = "color:#226666">Highwaympg : Fuel efficiency of a vehicle measured in miles(numeric) </p>
#    - <p style = "color:#226666">Price : Monetary value of the vehicle(numeric) </p>

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Excel file
df = pd.read_csv(r"C:\Users\hp\Desktop\GOMYCODE\GOMYCODE\Assignment\CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# Make a copy of the original dataframe
df1 = df.copy()

# %% [markdown]
# ### Data Exploration

# %%
# Checking for null values
df1.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
print(df1.dtypes)
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df1.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# checking the value distribution for columns with object data types
object_columns = df1.select_dtypes(include=['object']).columns

# Check value distribution for each object column
for column in object_columns:
    print(f"Value counts for {column}:")
    print(df1[column].value_counts())
    print("\n")
# Out:
# Value counts for CarName:
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: count, Length: 147, dtype: int64
#
#
# Value counts for fueltype:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64
#
#
# Value counts for aspiration:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64
#
#
# Value counts for doornumber:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64
#
#
# Value counts for carbody:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64
#
#
# Value counts for drivewheel:
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64
#
#
# ...

# %%
df1.shape
# Out:
# (205, 26)

# %% [markdown]
# ### Data Cleaning

# %%
# Drop unnecessary columns i.e car_ID and carName
columns_to_drop = ['car_ID', 'CarName']
df1 = df1.drop(columns=columns_to_drop, errors='ignore')

# %%
df1.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
#   boreratio stroke  compressionratio horsepower  peakrpm  citympg  highwaympg  \
# ...

# %%
header = []
for col in df1.columns:
    new_header = header.append(col.lower())
df1.columns = header

# %%
# Rename selected column names
df1 = df1.rename(columns={
    "fueltype": "fuel_type",
    "doornumber": "door_number", "carbody": "car_body",
    "drivewheel": "drive_wheel", "enginelocation": "engine_location",
    "wheelbase": "wheel_base", "enginesize": "engine_size",
    "fuelsystem": "fuel_system", "boreratio": "bore_ratio",
    "compressionratio": "compression_ratio", "horsepower": "horse_power",
    "peakrpm": "peak_rpm", "citympg": "city_mpg",
    "highwaympg": "high_waympg",
    })

# %%
#Using label encoder to transform the object columns to integer
# Identify object columns
object_columns = df1.select_dtypes(include=['object']).columns

from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to each object column
for col in object_columns:
    df1[col] = label_encoder.fit_transform(df1[col])

# %%
df1.head()
# Out:
#    symboling  fuel_type  aspiration  door_number  car_body  drive_wheel  \
# 0          3          1           0            1         0            2
# 1          3          1           0            1         0            2
# 2          1          1           0            1         2            2
# 3          2          1           0            0         3            1
# 4          2          1           0            0         3            0
#
#    engine_location  wheel_base  carlength  carwidth  ...  engine_size  \
# 0                0        88.6      168.8      64.1  ...          130
# 1                0        88.6      168.8      64.1  ...          130
# 2                0        94.5      171.2      65.5  ...          152
# 3                0        99.8      176.6      66.2  ...          109
# 4                0        99.4      176.6      66.4  ...          136
#
#    fuel_system  bore_ratio  stroke  compression_ratio  horse_power  peak_rpm  \
# ...

# %%
numerical_cols = df1.select_dtypes("number").columns
numerical_cols
# Out:
# Index(['symboling', 'fuel_type', 'aspiration', 'door_number', 'car_body',
#        'drive_wheel', 'engine_location', 'wheel_base', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'engine_size', 'fuel_system', 'bore_ratio', 'stroke',
#        'compression_ratio', 'horse_power', 'peak_rpm', 'city_mpg',
#        'high_waympg', 'price'],
#       dtype='object')

# %%
# so we might consider profile_score has a feature that will determine the car pricing 
df1.corr()["price"].sort_values(ascending= False)
# Out:
# price                1.000000
# engine_size          0.874145
# curbweight           0.835305
# horse_power          0.808139
# carwidth             0.759325
# carlength            0.682920
# drive_wheel          0.577992
# wheel_base           0.577816
# bore_ratio           0.553173
# fuel_system          0.526823
# engine_location      0.324973
# aspiration           0.177926
# carheight            0.119336
# stroke               0.079443
# compression_ratio    0.067984
# enginetype           0.049171
# cylindernumber      -0.027628
# door_number         -0.031835
# symboling           -0.079978
# car_body            -0.083976
# peak_rpm            -0.085267
# fuel_type           -0.105679
# city_mpg            -0.685751
# high_waympg         -0.697599
# Name: price, dtype: float64

# %%
# the dataframe.describe has indicated that there might be extreme values in those columns, we can still explore this further
df1[numerical_cols].hist(figsize=(16, 12)); #this used to see the distribution

# %%
#Checking the SKEW COLUMS graphically 
skewed_cols = ["engine_location", "aspiration", "carheight", "stroke", "compression_ratio", "enginetype","cylindernumber","door_number","symboling","car_body","peak_rpm","fuel_type","city_mpg","high_waympg"]

# %%
#correlation with applicant .  
sns.heatmap(data=df1.corr(), cmap="viridis", annot=True);

# %%
# Checking for outliers in the dataset 
def outliers_func():
        outliers_cols = []
    
        for col in df1.select_dtypes("number"): 
            q1 = df1[col].quantile(.25)
            q3 = df1[col].quantile(.75)
            iqr = q3 - q1
            lower_out= (df1[col] < (q1 - (1.5*iqr))).sum()
            upper_out = (df1[col]  > (q3 + (1.5*iqr))).sum()

            if lower_out > 0 or upper_out > 0 :
                outliers_cols.append(col)

        return outliers_cols

# %%
# calling the outliers function
outlier_columns = outliers_func()

# %%
outlier_columns
# Out:
# ['fuel_type',
#  'aspiration',
#  'car_body',
#  'engine_location',
#  'wheel_base',
#  'carlength',
#  'carwidth',
#  'enginetype',
#  'cylindernumber',
#  'engine_size',
#  'stroke',
#  'compression_ratio',
#  'horse_power',
#  'peak_rpm',
#  'city_mpg',
#  'high_waympg',
#  'price']

# %%
plt.figure(figsize=(16, 12))
num_columns = len(outlier_columns)  # Total number of outlier columns
nrows = (num_columns // 5) + 1  # Calculate the required number of rows

for index, col in enumerate(outlier_columns):
    plt.subplot(nrows, 5, index + 1)  # Create subplots dynamically based on the number of columns
    sns.boxplot(x=df1[col])  # Assuming you want to plot x against each outlier column

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()  # Show the plot

# %%
df1.price.unique()
# Out:
# array([13495.   , 16500.   , 13950.   , 17450.   , 15250.   , 17710.   ,
#        18920.   , 23875.   , 17859.167, 16430.   , 16925.   , 20970.   ,
#        21105.   , 24565.   , 30760.   , 41315.   , 36880.   ,  5151.   ,
#         6295.   ,  6575.   ,  5572.   ,  6377.   ,  7957.   ,  6229.   ,
#         6692.   ,  7609.   ,  8558.   ,  8921.   , 12964.   ,  6479.   ,
#         6855.   ,  5399.   ,  6529.   ,  7129.   ,  7295.   ,  7895.   ,
#         9095.   ,  8845.   , 10295.   , 12945.   , 10345.   ,  6785.   ,
#         8916.5  , 11048.   , 32250.   , 35550.   , 36000.   ,  5195.   ,
#         6095.   ,  6795.   ,  6695.   ,  7395.   , 10945.   , 11845.   ,
#        13645.   , 15645.   ,  8495.   , 10595.   , 10245.   , 10795.   ,
#        11245.   , 18280.   , 18344.   , 25552.   , 28248.   , 28176.   ,
#        31600.   , 34184.   , 35056.   , 40960.   , 45400.   , 16503.   ,
#         5389.   ,  6189.   ,  6669.   ,  7689.   ,  9959.   ,  8499.   ,
# ...

# %% [markdown]
# ### Data preprocessing Stage

# %%
outlier_col = ['fuel_type',
 'aspiration',
 'car_body',
 'engine_location',
 'wheel_base',
 'carlength',
 'carwidth',
 'enginetype',
 'cylindernumber',
 'engine_size',
 'stroke',
 'compression_ratio',
 'horse_power',
 'peak_rpm',
 'city_mpg',
 'high_waympg',
 'price']

# %%
#Transforming the skewed columns
df1[outlier_col] = df1[outlier_col].apply(lambda x: np.log(x + 1))

# %%
# The figure below shows that the columns have been transformed nicely to its maximum
df1[outlier_col].hist(figsize=(8, 6));

# %% [markdown]
# ## Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

# %%
# Assuming you have a DataFrame df with your features and target variable
X = df1.drop(['price'],axis=1)
Y = df1['price']

# %%
print(Y)
# Out:
# 0       9.510149
# 1       9.711176
# 2       9.711176
# 3       9.543306
# 4       9.767152
#          ...
# 200     9.731869
# 201     9.854612
# 202     9.975157
# 203    10.019981
# 204    10.026855
# Name: price, Length: 205, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size= 0.2, random_state= 42)

# %%
#: Define and train the model (example using Linear Regression)
model = LinearRegression()  # or use other models like DecisionTreeRegressor(), RandomForestRegressor(), SVR()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#: Generate predictions on the training data
training_data_prediction = model.predict(X_train)
test_data_prediction = model.predict(X_test)  # Predictions for test data

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (164, 23) (41, 23)
# (164,) (41,)

# %%
X_test
# Out:
#      symboling  fuel_type  aspiration  door_number  car_body  drive_wheel  \
# 15           0   0.693147    0.000000            0  1.386294            2
# 9            0   0.693147    0.693147            1  1.098612            0
# 100          0   0.693147    0.000000            0  1.386294            1
# 132          3   0.693147    0.000000            1  1.098612            1
# 68          -1   0.000000    0.693147            0  1.609438            2
# 95           1   0.693147    0.000000            1  1.098612            1
# 159          0   0.000000    0.000000            0  1.098612            1
# 162          0   0.693147    0.000000            0  1.386294            1
# 147          0   0.693147    0.000000            0  1.609438            1
# 182          2   0.000000    0.000000            1  1.386294            1
# 191          0   0.693147    0.000000            0  1.386294            1
# 164          1   0.693147    0.000000            1  1.098612            2
# ...

# %%
y_test
# Out:
# 15     10.334003
# 9       9.790328
# 100     9.164296
# 132     9.380168
# 68     10.248813
# 95      8.961879
# 159     8.960468
# 162     9.133351
# 147     9.230045
# 182     8.958797
# 191     9.495219
# 164     9.016634
# 65      9.813618
# 175     9.209240
# 73     10.620376
# 152     8.777864
# 18      8.547140
# 82      9.443830
# 86      9.010669
# 143     9.206433
# 60      9.047351
# 101     9.510445
# 98      9.017968
# 30      8.776476
# 25      8.808817
# 16     10.629005
# 168     9.173676
# 195     9.504203
# 97      8.987197
# 194     9.468156
# 67     10.148510
# 120     8.737132
# 154     8.974491
# 202     9.975157
# 79      8.947676
# 69     10.246261
# 145     9.329012
# 55      9.300729
# 45      9.095771
# 84      9.581214
# 146     8.917847
# Name: price, dtype: float64

# %%
# Putting regression models in a dictionary
regression_models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "SVR": SVR()
}

# %%
# Function to fit, predict, and score regression models
def fit_predict_and_score_regression(models, X_train, X_test, y_train, y_test):
    for name, model in models.items():
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        print(f"{name} - Train Score: {model.score(X_train, y_train)}, Test Score: {model.score(X_test, y_test)}")

# Fit, predict, and score the regression models
fit_predict_and_score_regression(regression_models, X_train, X_test, y_train, y_test)
# Out:
# Linear Regression - Train Score: 0.9135252203707578, Test Score: 0.8488073207391957
# Decision Tree Regressor - Train Score: 0.9989156672352937, Test Score: 0.9247436691236712
# Random Forest Regressor - Train Score: 0.9879173434852848, Test Score: 0.9529881200111125
# SVR - Train Score: 0.7740291905334193, Test Score: 0.8712202516403387

# %%
# Visualizing the actual price and the predicted prices
#this sugest a strong relationship actual price and the predicted prices
plt.scatter(y_train, training_data_prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual vs Predicted Prices")
plt.show()

# %% [markdown]
# #: Visualize the actual vs. predicted prices for test data
# plt.scatter(y_test, test_data_prediction)  # Ensure this variable is defined
# plt.xlabel("Actual price")
# plt.ylabel("Predicted price")
# plt.title("Actual vs Predicted Prices (Test Data)")
# plt.show()

# %% [markdown]
# #### Evaluation

# %% [markdown]
# #Evaluation: Linear Regression shows a balanced performance with relatively close training and test scores, indicating good generalization
#
# #:The Decision Tree Regressor has a very high train score, suggesting potential overfitting. However, the test score is also quite high, indicating that the model performs well on the test set despite potential overfitting.
#
#  #:The Random Forest Regressor performs the best among all models with high training and test scores. This indicates that it has a good balance between fitting the training data and generalizing to unseen data.
#
# #:The SVR has the lowest train score among the models, indicating it might be underfitting the training data. However, it has a relatively high test score, which suggests it performs well on unseen data but might benefit from further tuning.

# %% [markdown]
# ### Evaluating model performance
# I evaluated the performance of the two models (Random Forest Regressor & Decision Tree Regressor) that have better score on the test dataset

# %%
import pickle

# %%
filename = "CarPrice_Assignment. 2.0.sav"
pickle.dump(rand, open(filename, "wb"))

# %% [markdown]
# ## Streamlit & deployment

# %%
X_test.columns
# Out:
# Index(['symboling', 'fuel_type', 'aspiration', 'door_number', 'car_body',
#        'drive_wheel', 'engine_location', 'wheel_base', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'engine_size', 'fuel_system', 'bore_ratio', 'stroke',
#        'compression_ratio', 'horse_power', 'peak_rpm', 'city_mpg',
#        'high_waympg'],
#       dtype='object')
